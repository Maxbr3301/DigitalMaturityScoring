# %%
# Original dictionaries
cybersecurity_governance = {
    "Data Management": {
        "Robust Data Governance": ["data governance frameworks", "data policy formulation", "data stewardship practices", "data governance", "information policy", "data strategy", "data stewardship", "compliance"],
        "Lifecycle Data Management": ["data lifecycle planning", "data retention strategies", "information lifecycle management"],
        "Secure Data Protocols": ["data security protocols", "encryption standard implementation", "data access controls"],
        "Comprehensive Data Auditing": ["data audit procedures", "audit trail management", "data compliance checks"],
        "Information Architecture Optimization": ["information architecture design", "data structuring techniques", "system integration planning"],
        "Access Control Systems": ["access management solutions", "authentication mechanisms", "authorization protocols"],
        "Data Backup and Recovery": ["data backup procedures", "disaster recovery planning", "data replication techniques"]
    },
    "Compliance Assurance": {
        "Regulatory Compliance Alignment": ["regulatory compliance strategies", "legal standards adherence", "regulatory framework application"],
        "Compliance Training Programs": ["staff compliance training", "legal awareness sessions", "regulatory training modules"],
        "Policy and Legal Compliance Review": ["policy compliance checks", "legal review processes", "regulatory audit practices"],
        "Effective Policy Implementation": ["compliance policy deployment", "policy enforcement mechanisms", "regulatory adherence measures"],
        "Compliance Auditing and Monitoring": ["compliance audit techniques", "compliance tracking systems", "audit log maintenance"],
        "Risk Assessment and Management": ["risk management frameworks", "risk mitigation strategies", "risk analysis methods"],
        "Standardized Compliance Reporting": ["compliance report generation", "regulatory reporting standards", "compliance documentation"]
    },
    "Efficiency Auditing": {
        "Performance Efficiency Analysis": ["performance evaluation metrics", "efficiency analysis tools", "productivity assessment techniques"],
        "Process and Workflow Evaluation": ["workflow efficiency audits", "process performance reviews", "operational evaluation systems"],
        "Resource Utilization Review": ["resource allocation analysis", "asset utilization studies", "resource efficiency assessments"],
        "Technology and Auditing Tools": ["audit technology applications", "technology review practices", "audit tool utilization"],
        "Cost-Benefit and ROI Analysis": ["financial performance analysis", "cost-benefit assessments", "ROI calculation methods"],
        "Operational Review and Inspection": ["operational review processes", "audit inspection techniques", "efficiency inspection strategies"],
        "Benchmarking and Best Practices": ["performance benchmarking methods", "industry standards analysis", "best practice identification"]
    },
    "Data Integrity": {
        "Data Integrity Assurance": ["data accuracy checks", "integrity testing methods", "data validation protocols"],
        "Error Detection and Correction": ["error detection mechanisms", "data quality improvement", "error correction processes"],
        "Consistency and Standardization": ["data consistency maintenance", "data standardization efforts", "synchronization techniques"],
        "Data Quality Metrics and Indicators": ["quality measurement standards", "data quality metrics", "performance indicator systems"],
        "Data Integrity Policy and Standards": ["data integrity guidelines", "data policy formulation", "quality control standards"],
        "Comprehensive Data Cleansing": ["data cleaning processes", "data purification methods", "data sanitization techniques"]
    },
    "Reputation Safeguarding": {
        "Brand and Reputation Monitoring": ["brand reputation analysis", "online reputation tracking", "public perception monitoring"],
        "Crisis Management and Response": ["crisis response planning", "emergency management strategies", "reputation recovery actions"],
        "Public Relations and Image Management": ["PR management tactics", "media relations strategies", "public image enhancement"],
        "Customer Feedback and Insights": ["client feedback analysis", "customer satisfaction studies", "consumer opinion tracking"],
        "Digital Presence and Online Reputation": ["digital footprint management", "social media reputation", "online presence optimization"],
        "Strategic Reputation Planning": ["reputation management strategies", "brand strategy development", "image management planning"],
        "Media Communication and Relations": ["media communication policies", "press relationship management", "public announcement strategies"]
    }
}

cybersecurity_governance_second = {
    "Data Management": {
        "Data Governance": ["data governance", "information policy", "data strategy", "data stewardship", "compliance"],
        "Lifecycle Management": ["data lifecycle", "information lifecycle", "data retention", "data disposal", "data archiving"],
        "Security Protocols": ["security protocols", "data protection", "encryption standards", "access control", "security measures"],
        "Data Auditing": ["data auditing", "audit trails", "compliance checks", "data verification", "audit reports"],
        "Information Architecture": ["information architecture", "data structuring", "system design", "data integration", "architecture planning"],
        "Access Control": ["access control", "authorization", "authentication", "user access", "security permissions"],
        "Backup Strategies": ["backup strategies", "data backup", "redundancy planning", "disaster recovery", "data replication"]
    },
    "Compliance Assurance": {
        "Regulatory Alignment": ["regulatory compliance", "legal standards", "industry regulations", "compliance alignment", "regulatory adherence"],
        "Compliance Training": ["compliance training", "staff education", "legal training", "policy training", "regulatory education"],
        "Legal Review": ["legal review", "compliance review", "legal assessment", "regulatory examination", "legal analysis"],
        "Policy Implementation": ["policy implementation", "compliance policies", "policy enforcement", "regulatory policies", "policy management"],
        "Audit Trails": ["audit trails", "audit logs", "compliance tracking", "record keeping", "transaction logging"],
        "Risk Management": ["risk management", "risk assessment", "risk mitigation", "risk analysis", "risk strategies"],
        "Reporting Standards": ["reporting standards", "compliance reporting", "regulatory reports", "reporting requirements", "standardized reporting"]
    },
    "Efficiency Auditing": {
        "Performance Analysis": ["performance analysis", "efficiency evaluation", "productivity assessment", "performance metrics", "operational analysis"],
        "Process Evaluation": ["process evaluation", "workflow analysis", "operational review", "process assessment", "efficiency review"],
        "Resource Utilization": ["resource utilization", "asset management", "resource efficiency", "usage analysis", "resource allocation"],
        "Auditing Technology": ["auditing technology", "audit tools", "technology review", "tech assessment", "audit software"],
        "Cost-Benefit Analysis": ["cost-benefit analysis", "financial assessment", "cost analysis", "benefit evaluation", "ROI analysis"],
        "Operational Review": ["operational review", "operational audit", "process inspection", "operational efficiency", "operational performance"],
        "Benchmarking": ["benchmarking", "performance benchmarking", "industry standards", "comparative analysis", "best practice comparison"]
    },
    "Data Integrity": {
        "Integrity Checks": ["integrity checks", "data verification", "accuracy testing", "consistency review", "validation checks"],
        "Error Detection": ["error detection", "data quality", "anomaly detection", "error identification", "data correction"],
        "Data Validation": ["data validation", "validation procedures", "accuracy assurance", "data confirmation", "quality control"],
        "Consistency Maintenance": ["consistency maintenance", "data uniformity", "standardization", "synchronization", "data alignment"],
        "Quality Metrics": ["quality metrics", "quality standards", "performance indicators", "quality measurement", "quality indicators"],
        "Integrity Standards": ["integrity standards", "data principles", "quality guidelines", "data criteria", "standard practices"],
        "Data Cleansing": ["data cleansing", "data cleaning", "data purification", "data scrubbing", "data sanitization"]
    },
    "Reputation Safeguarding": {
        "Brand Monitoring": ["brand monitoring", "reputation tracking", "brand reputation", "online monitoring", "public perception"],
        "Crisis Management": ["crisis management", "emergency response", "crisis response", "reputation recovery", "damage control"],
        "Public Relations": ["public relations", "PR management", "media relations", "public image", "communications strategy"],
        "Customer Feedback": ["customer feedback", "client reviews", "feedback analysis", "customer satisfaction", "consumer opinions"],
        "Online Presence": ["online presence", "digital footprint", "social media presence", "web reputation", "online image"],
        "Reputation Strategy": ["reputation strategy", "reputation planning", "brand strategy", "reputation management", "image strategy"],
        "Media Relations": ["media relations", "press management", "media strategy", "public announcements", "media engagement"]
    }
}

merged_governance = {}

# Get a list of categories from the first dictionary in the order they appear
categories_order = list(cybersecurity_governance.keys())

# Iterate through the categories in the order they appear
for category in categories_order:
    merged_category = {}
    
    # Iterate through the subcategories in the first dictionary
    for subcategory, keywords in cybersecurity_governance[category].items():
        # Check if the category and subcategory exist in the second dictionary
        if category in cybersecurity_governance_second and subcategory in cybersecurity_governance_second[category]:
            merged_category[subcategory] = keywords + cybersecurity_governance_second[category][subcategory]
        else:
            merged_category[subcategory] = keywords
    
    merged_governance[category] = merged_category

# Print the merged dictionary
import pprint
pprint.pprint(merged_governance, width=120)
print(merged_governance)
# Out:
# {'Compliance Assurance': {'Compliance Auditing and Monitoring': ['compliance audit techniques',
#                                                                  'compliance tracking systems',
#                                                                  'audit log maintenance'],
#                           'Compliance Training Programs': ['staff compliance training',
#                                                            'legal awareness sessions',
#                                                            'regulatory training modules'],
#                           'Effective Policy Implementation': ['compliance policy deployment',
#                                                               'policy enforcement mechanisms',
#                                                               'regulatory adherence measures'],
#                           'Policy and Legal Compliance Review': ['policy compliance checks',
# ...
